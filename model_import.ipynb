# %%
import os
import sys
import json
import subprocess
import numpy as np
import torch
from torch import nn

from models.ResNet_3D.opts import create_args
from models.ResNet_3D.model import generate_model
from misc.mean import get_mean, get_std

# %%
model_pth = '/home/nevin/nevin/weights/3D-resnet/resnext-101-kinetics.pth'

# %%
opt = create_args(model_name = 'resnext', model_depth=101, \
                  model=model_pth, no_cuda=True)
opt.mean = get_mean()
opt.arch = '{}-{}'.format(opt.model_name, opt.model_depth)
opt.sample_size = 112
opt.sample_duration = 16
opt.n_classes = 400

# %%
model = generate_model(opt)
print('loading model {}'.format(opt.model))
if(opt.no_cuda):
    model_data = torch.load(opt.model, map_location='cpu')
else:
    model_data = torch.load(opt.model)
assert opt.arch == model_data['arch']
model.load_state_dict(model_data['state_dict'],strict=False)
model = model.eval()
# Out:
# loading model /home/nevin/nevin/weights/3D-resnet/resnext-101-kinetics.pth

# %%
tens = torch.rand((1, 3, 16, 112, 112), requires_grad=False)
model(tens)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-5cbfcfe1c76c> in <module>()
#       1 tens = torch.rand((1, 3, 16, 112, 112), requires_grad=False)
# ----> 2 model(tens)
#
# ~/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/nevin/projects/ml/3D-ResNets-PyTorch/models/resnext.py in forward(self, x)
#     125         x = self.maxpool(x)
#     126
# --> 127         x = self.layer1(x)
#     128         x = self.layer2(x)
#     129         x = self.layer3(x)
#
# ~/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/nevin/projects/ml/3D-ResNets-PyTorch/models/resnext.py in forward(self, x)
#      60
#      61         if self.downsample is not None:
# ---> 62             residual = self.downsample(x)
#      63
#      64         out += residual
#
# ~/nevin/projects/ml/3D-ResNets-PyTorch/models/resnext.py in downsample_basic_block(x, planes, stride)
#      20                              out.size(2), out.size(3),
#      21                              out.size(4)).zero_()
# ---> 22     if isinstance(out.data, torch.cuda.FloatTensor):
#      23         zero_pads = zero_pads.cuda()
#      24
#
# RuntimeError: Cannot initialize CUDA without ATen_cuda library. PyTorch splits its backend into two shared libraries: a CPU library and a CUDA library; this error has occurred because you are trying to use some CUDA functionality, but the CUDA library has not been loaded by the dynamic linker for some reason.  The CUDA library MUST be loaded, EVEN IF you don't directly use any symbols from the CUDA library! One common culprit is a lack of -Wl,--no-as-needed in your link arguments; many dynamic linkers will delete dynamic library dependencies if you don't depend on any of their symbols.  You can check if this has occurred by using ldd on your binary to see if there is a dependency on *_cuda.so library.
